# %% [markdown]
# <a href="https://colab.research.google.com/github/Kudrettinkadir/samples/blob/master/sklearn_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

iris = sns.load_dataset("iris")
#iris.head()

iris["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
import seaborn as sns
sns.pairplot(iris, hue="species",size=1.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
iris.shape
# Out:
# (150, 5)

# %%
x_iris = iris.drop("species",axis=1)
x_iris.shape
#type(x_iris)
# Out:
# (150, 4)

# %%
y_iris = iris["species"]#etiket
y_iris.shape
# Out:
# (150,)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_iris,y_iris)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_predicted =model.predict(x_iris)
from sklearn.metrics import accuracy_score

accuracy_score(y_predicted,y_iris)
# Out:
# 0.96

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
rng = np.random.RandomState(42)
x = 10* rng.rand(100)
y = 3 * x -5+ rng.randn(100)

# %%
 plt.scatter(x,y,)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression(fit_intercept=True)
x_ =  x[:,np.newaxis]
x_

# %%
model.fit(x_,y)

y_predicted = model.predict(x_)
plt.scatter(x,y)
plt.plot(x,y_predicted)
